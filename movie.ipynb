# %%
import pandas as pd

# %%
movies= pd.read_csv('C:\\Users\\DELL\\Desktop\\uni\\movies.csv')

# %% [markdown]
# movies

# %%
movies
# Out:
#     Position                                              Title  IMDb Rating  \
# 0          1                           The Shawshank Redemption          9.3
# 1          2                                      The Godfather          9.2
# 2          3                             The Godfather: Part II          9.0
# 3          4                                    The Dark Knight          9.0
# 4          5                                       12 Angry Men          8.9
# 5          6                                   Schindler's List          8.9
# 6          7      The Lord of the Rings: The Return of the King          8.9
# 7          8                                       Pulp Fiction          8.9
# 8          9                    Il buono, il brutto, il cattivo          8.8
# 9         10                                         Fight Club          8.8
# 10        11                                              Joker          8.5
# ...

# %%
movies.head()
# Out:
#    Position                     Title  IMDb Rating  Runtime (mins)  Year  \
# 0         1  The Shawshank Redemption          9.3             142  1994
# 1         2             The Godfather          9.2             175  1972
# 2         3    The Godfather: Part II          9.0             202  1974
# 3         4           The Dark Knight          9.0             152  2008
# 4         5              12 Angry Men          8.9              96  1957
#
#               Directors
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2  Francis Ford Coppola
# 3     Christopher Nolan
# 4          Sidney Lumet

# %%
movies.columns=('pos','title','rating','runtime','year','directors')

# %%
movies.head()
# Out:
#    pos                     title  rating  runtime  year             directors
# 0    1  The Shawshank Redemption     9.3      142  1994        Frank Darabont
# 1    2             The Godfather     9.2      175  1972  Francis Ford Coppola
# 2    3    The Godfather: Part II     9.0      202  1974  Francis Ford Coppola
# 3    4           The Dark Knight     9.0      152  2008     Christopher Nolan
# 4    5              12 Angry Men     8.9       96  1957          Sidney Lumet

# %%
movies.describe()
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pos        35 non-null     int64
#  1   title      35 non-null     object
#  2   rating     35 non-null     float64
#  3   runtime    35 non-null     int64
#  4   year       35 non-null     int64
#  5   directors  35 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.8+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=12,8
import warnings
warnings.filterwarnings("ignore")

# %%
vis=sns.scatterplot(data= movies , x='year',y= 'rating' ,marker="s" , color='green',hue='runtime')

# %%
vis=sns.scatterplot(data= movies , x='runtime',y= 'rating' , color='green')

# %%
sas

# %%
sas.head()

# %%
sas.columns=('rank','peak','title','year')

# %%
sas.head().describe

# %%
sas.head().info

# %%
sas.head().higest.astype('category')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=15,12
import warnings
warnings.filterwarnings('ignore')

# %%
j= sns.jointplot(data= sas ,x='rank', y='peak')

# %%
movies.head()

# %%
movies.columns=("pos","title","rating","runtime","year","director")

# %%
movies

# %%
vis= sns.scatterplot(data= movies, y='title', x='rating' )
